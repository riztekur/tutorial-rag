# %%
from chonkie import SemanticChunker
from pathlib import Path

# %%
text = Path("documents/bandung.md").read_text(encoding="utf-8")

# %%
chunker = SemanticChunker(
    embedding_model="minishlab/potion-base-32M",
    threshold=0.95,
    chunk_size=512
)

# %%
chunks = chunker.chunk(text)

# %%
len(chunks)
# Out:
# 38

# %%
chunks
# Out:
# [Chunk(text='# Menjelajahi Pesona Kota Bandung: Paris van Java
#
#  Bandung, ibu kota Provinsi Jawa Barat, telah lama menjadi primadona pariwisata di Indonesia. Dikenal dengan julukan "Paris van Java" sejak era kolonial, kota ini menawarkan perpaduan unik antara keindahan alam yang sejuk, arsitektur bersejarah yang menawan, kreativitas anak muda, serta surga kuliner dan belanja.
#
#  Julukan itu merujuk pada suasana kota di masa lalu yang menyerupai Paris, dengan jalan-jalan yang rindang, bangunan art deco yang elegan, dan gaya hidup masyarakatnya. ', token_count=163, start_index=0, end_index=534),
#  Chunk(text='Kini, Bandung telah bertransformasi menjadi metropolitan yang dinamis—sebuah "kawah candradimuka" bagi ide kreatif, mode, dan gastronomi.
#  ', token_count=47, start_index=534, end_index=672),
#  Chunk(text='
#  ## Wisata Alam dan Dataran Tinggi
#
#  Bandung dikelilingi pegunungan, ideal untuk menikmati udara segar dan pemandangan alam spektakuler.
#  ', token_count=42, start_index=672, end_index=808),
#  Chunk(text='
#  ### Kawasan Lembang (Bandung Utara)
#  ', token_count=13, start_index=808, end_index=845),
#  Chunk(text='
#  Lembang adalah destinasi wajib pecinta alam. Udaranya sejuk dan pemandangannya hijau memanjakan mata. _Catatan: akhir pekan biasanya padat._
#  ', token_count=50, start_index=845, end_index=987),
#  Chunk(text='
#  - **Tangkuban Perahu** — Gunung berapi aktif ikon Jawa Barat. ', token_count=24, start_index=987, end_index=1050),
#  Chunk(text='Bisa berkendara hingga bibir Kawah Ratu. Kawah Domas memungkinkan melihat kawah dari dekat dan merebus telur di sumber air panas.
#  - **Farmhouse Lembang** — Suasana peternakan ala Eropa, bangunan bergaya Belanda, miniatur rumah Hobbit, interaksi dengan domba dan kelinci. ', token_count=89, start_index=1050, end_index=1321),
#  Chunk(text='Tiket masuk dapat ditukar segelas susu murni.
#  ', token_count=18, start_index=1321, end_index=1367),
#  Chunk(text='- **Floating Market (Pasar Terapung)** — Pasar kuliner unik di atas danau. Ada jajanan lokal sampai makanan Jepang, wahana permainan, taman kelinci, dan sewa kostum tradisional.
#  ', token_count=61, start_index=1367, end_index=1545),
#  Chunk(text='- **The Great Asia Africa** — Replika landmark dan suasana desa dari berbagai negara di Asia dan Afrika, lengkap dengan kostum tradisional.
#  - **The Lodge Maribaya** — Wahana foto instagrammable di hutan pinus: Sky Swing, Zip Bike, dan balon udara.
#  - **Dusun Bambu** — Taman rekreasi keluarga berkonsep ekowisata: suasana pedesaan Sunda, restoran tepi danau (Lutung Kasarung), area bermain anak, hingga vila penginapan.
#
#  ### Kawasan Ciwidey (Bandung Selatan)
#
#  Ciwidey menawarkan pesona alam berbeda: kawah vulkanik, danau, serta hamparan kebun teh yang menyejukkan.
#
#  - **Kawah Putih** — Danau kawah vulkanik dengan pemandangan sureal. ', token_count=217, start_index=1545, end_index=2179),
#  Chunk(text='Air danau berubah warna, tanah kapur putih dramatis dan fotogenik. ', token_count=21, start_index=2179, end_index=2246),
#  Chunk(text='_Aroma belerang cukup kuat—batasi durasi kunjungan._
#  ', token_count=20, start_index=2246, end_index=2299),
#  Chunk(text='- **Glamping Lakeside Rancabali** — Ikonik dengan **Pinisi Resto** berbentuk kapal di tepi **Situ Patenggang**. Pemandangan danau indah, jembatan gantung panjang, dan area glamping.
#  - **Situ Patenggang** — Danau dikelilingi kebun teh. Legenda **Batu Cinta** jadi daya tarik. ', token_count=97, start_index=2299, end_index=2574),
#  Chunk(text='Bisa sewa perahu untuk berkeliling.
#  - **Ranca Upas** — Pusat penangkaran Rusa Jawa. Bisa memberi makan rusa jinak di padang rumput luas. ', token_count=46, start_index=2574, end_index=2711),
#  Chunk(text='Tersedia pemandian air panas alami.
#
#  ## Wisata Sejarah, Budaya, dan Perkotaan
#
#  Pusat kota Bandung menyimpan banyak cerita sejarah dan bangunan ikonik yang terawat.
#
#  ### Ikon Sejarah dan Arsitektur
#
#  - **Gedung Sate** — Mahakarya art deco dengan sentuhan nusantara (atap mirip pura Bali). ', token_count=95, start_index=2711, end_index=2998),
#  Chunk(text='"Tusuk sate" menjadi ciri khas. ', token_count=13, start_index=2998, end_index=3030),
#  Chunk(text='Taman terbuka untuk umum; ada museum di bagian bawah.
#  - **Jalan Braga** — Jantung kota masa kolonial. Bangunan art deco tua kini jadi kafe, galeri, restoran, dan toko roti legendaris. ', token_count=60, start_index=3030, end_index=3214),
#  Chunk(text='Trotoar lebar nyaman untuk pejalan kaki.
#  - **Museum Konferensi Asia Afrika** — Di Gedung Merdeka. Menyimpan diorama, foto, dan ruang konferensi asli Konferensi Asia Afrika 1955.
#  ', token_count=57, start_index=3214, end_index=3392),
#  Chunk(text='- **Gedung Indonesia Menggugat** — Bekas Landraad tempat Soekarno diadili dan membacakan pidato "Indonesia Menggugat".
#  - **Kawasan Dago** — Area factory outlet dan kafe, banyak vila peninggalan Belanda. **Dago Tea House** menyuguhkan pemandangan kota dari ketinggian.
#  ', token_count=92, start_index=3392, end_index=3660),
#  Chunk(text='
#  ### Seni dan Kreativitas
#
#  - **Saung Angklung Udjo** — Didedikasikan untuk pelestarian budaya Sunda, khusus angklung. Pertunjukan musik, wayang golek, tari; puncaknya main angklung bersama.
#  ', token_count=74, start_index=3660, end_index=3850),
#  Chunk(text='- **NuArt Sculpture Park** — Galeri milik I Nyoman Nuarta. Patung-patung logam raksasa di galeri indoor dan taman outdoor yang asri.
#  - **Selasar Sunaryo Art Space** — Ruang seni kontemporer dengan pameran, diskusi, dan pertunjukan. ', token_count=79, start_index=3850, end_index=4082),
#  Chunk(text='Arsitektur unik dan kafe menghadap lembah.
#  ', token_count=15, start_index=4082, end_index=4125),
#  Chunk(text='
#  ## Surga Kuliner dan Belanja
#
#  Bandung tidak lengkap tanpa wisata kuliner dan belanja yang tiada habisnya.
#
#  ### Jajanan Khas dan Kuliner Legendaris
#  ', token_count=46, start_index=4125, end_index=4273),
#  Chunk(text='
#  - **Surabi** — Varian modern beragam, dari durian keju hingga oncom pedas. ', token_count=26, start_index=4273, end_index=4349),
#  Chunk(text='Populer: Surabi Enhaii (Jl. ', token_count=12, start_index=4349, end_index=4377),
#  Chunk(text='Setiabudi).
#  - **Batagor & Siomay** — Olahan ikan dan tahu dengan bumbu kacang kental. Legendaris: Batagor Kingsley, Batagor Riri.
#  - **Seblak** — Kerupuk basah dimasak bumbu cabai-kencur dengan aneka topping; sangat populer.
#  - **Kawasan Punclut** — Pemandangan kota dari ketinggian sambil menikmati nasi timbel, ayam bakar, sambal dadak di warung lesehan.
#  ', token_count=126, start_index=4377, end_index=4732),
#  Chunk(text='- **Mie Kocok** — Mie kuning pipih berkuah kaldu sapi, tauge, bakso, kikil lembut. ', token_count=35, start_index=4732, end_index=4815),
#  Chunk(text='Terkenal: Mie Kocok Mang Dadeng.
#  - **Kue Balok** — Kue cetakan balok di atas bara api; varian lumer setengah matang tengahnya.
#  - **Yoghurt Cisangkuy** — Yoghurt klasik (kental/encer) dengan sirup buah, suasana rindang dan sejuk di tengah kota.
#  ', token_count=91, start_index=4815, end_index=5059),
#  Chunk(text='
#  ### Pusat Belanja (Fashion)
#
#  - **Jalan Cihampelas** — Dulu "Jalan Jeans" dengan fasad superhero raksasa. Kini ada **Cihampelas Walk (Ciwalk)** dan **Teras Cihampelas** (jembatan layang pejalan kaki).
#  ', token_count=76, start_index=5059, end_index=5260),
#  Chunk(text='- **Factory Outlet (Jalan Riau & Dago)** — Pelopor FO di Indonesia. Menjual sisa ekspor pakaian bermerek dengan harga miring: Rumah Mode, The Summit, The Secret.
#  ', token_count=52, start_index=5260, end_index=5422),
#  Chunk(text='- **Distro (Distribution Outlet)** — Budaya fashion independen lokal. ', token_count=21, start_index=5422, end_index=5492),
#  Chunk(text='Pusatnya di Jl. Trunojoyo dan Jl. ', token_count=13, start_index=5492, end_index=5526),
#  Chunk(text='Sultan Agung.
#  - **Pasar Baru Trade Center** — Surga tekstil, kain, dan pakaian grosir; favorit wisatawan domestik dan mancanegara.
#
#  ## Tips Praktis Berwisata di Bandung
#  ', token_count=56, start_index=5526, end_index=5695),
#  Chunk(text='
#  - **Lalu Lintas** — Hindari Lembang/Ciwidey saat puncak akhir pekan (Sabtu pagi, Minggu sore). Gunakan aplikasi peta untuk memantau kemacetan.
#  - **Cuaca** — Malam hari dan setelah hujan bisa sangat dingin, terutama di Lembang dan Ciwidey. ', token_count=86, start_index=5695, end_index=5935),
#  Chunk(text='Siapkan jaket atau pakaian hangat.
#  ', token_count=12, start_index=5935, end_index=5970),
#  Chunk(text='- **Waktu Terbaik** — Hari kerja (Senin–Jumat) lebih tenang. Jika akhir pekan, berangkat lebih pagi untuk mengurangi risiko macet.
#  ', token_count=49, start_index=5970, end_index=6101),
#  Chunk(text='- **Oleh-oleh** — Pisang Bolen **Kartika Sari**, Brownies **Amanda**, dan keripik tempe di Cihampelas layak dicoba.
#  ', token_count=44, start_index=6101, end_index=6217),
#  Chunk(text='
#  Bandung adalah kota yang dinamis; selalu ada tempat baru untuk dijelajahi di setiap sudutnya. Kota ini memadukan warisan masa lalu dengan energi kreatif masa kini, menjadikannya destinasi yang tak pernah membosankan—selalu mengundang untuk kembali.', token_count=77, start_index=6217, end_index=6466)]

# %%
print(chunks[0].text)
# Out:
# # Menjelajahi Pesona Kota Bandung: Paris van Java
#
# Bandung, ibu kota Provinsi Jawa Barat, telah lama menjadi primadona pariwisata di Indonesia. Dikenal dengan julukan "Paris van Java" sejak era kolonial, kota ini menawarkan perpaduan unik antara keindahan alam yang sejuk, arsitektur bersejarah yang menawan, kreativitas anak muda, serta surga kuliner dan belanja.
#
# Julukan itu merujuk pada suasana kota di masa lalu yang menyerupai Paris, dengan jalan-jalan yang rindang, bangunan art deco yang elegan, dan gaya hidup masyarakatnya.

# %%
print(chunks[1].text)
# Out:
# Kini, Bandung telah bertransformasi menjadi metropolitan yang dinamis—sebuah "kawah candradimuka" bagi ide kreatif, mode, dan gastronomi.

# %%
print(chunks[2].text)
# Out:
# ## Wisata Alam dan Dataran Tinggi
#
# Bandung dikelilingi pegunungan, ideal untuk menikmati udara segar dan pemandangan alam spektakuler.

# %%
print(chunks[3].text)
# Out:
# ### Kawasan Lembang (Bandung Utara)

# %%
print(chunks[4].text)
# Out:
# Lembang adalah destinasi wajib pecinta alam. Udaranya sejuk dan pemandangannya hijau memanjakan mata. _Catatan: akhir pekan biasanya padat._
