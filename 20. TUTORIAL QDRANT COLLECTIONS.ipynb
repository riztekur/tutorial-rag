# %%
from qdrant_client import QdrantClient, models

# %%
client = QdrantClient(url="localhost:6333")

# %%
# membuat collection

client.create_collection(collection_name="my_collection")
# Out:
# True

# %%
client.create_collection(collection_name="my_collection")
# Out:
# ---------------------------------------------------------------------------
# UnexpectedResponse                        Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 client.create_collection(collection_name="my_collection")
#
# File c:\Users\Rizki Teguh\Desktop\tutorial-rag\.venv\Lib\site-packages\qdrant_client\qdrant_client.py:2382, in QdrantClient.create_collection(self, collection_name, vectors_config, sparse_vectors_config, shard_number, sharding_method, replication_factor, write_consistency_factor, on_disk_payload, hnsw_config, optimizers_config, wal_config, quantization_config, init_from, timeout, strict_mode_config, **kwargs)
#    2332 """Create empty collection with given parameters
#    2333
#    2334 Args:
#    (...)   2378     Operation result
#    2379 """
#    2380 assert len(kwargs) == 0, f"Unknown arguments: {list(kwargs.keys())}"
# -> 2382 return self._client.create_collection(
#    2383     collection_name=collection_name,
#    2384     vectors_config=vectors_config,
#    2385     shard_number=shard_number,
#    2386     sharding_method=sharding_method,
#    2387     replication_factor=replication_factor,
#    2388     write_consistency_factor=write_consistency_factor,
#    2389     on_disk_payload=on_disk_payload,
#    2390     hnsw_config=hnsw_config,
#    2391     optimizers_config=optimizers_config,
#    2392     wal_config=wal_config,
#    2393     quantization_config=quantization_config,
#    2394     init_from=init_from,
#    2395     timeout=timeout,
#    2396     sparse_vectors_config=sparse_vectors_config,
#    2397     strict_mode_config=strict_mode_config,
#    2398     **kwargs,
#    2399 )
#
# File c:\Users\Rizki Teguh\Desktop\tutorial-rag\.venv\Lib\site-packages\qdrant_client\qdrant_remote.py:2815, in QdrantRemote.create_collection(self, collection_name, vectors_config, shard_number, replication_factor, write_consistency_factor, on_disk_payload, hnsw_config, optimizers_config, wal_config, quantization_config, init_from, timeout, sparse_vectors_config, sharding_method, strict_mode_config, **kwargs)
#    2797     init_from = GrpcToRest.convert_init_from(init_from)
#    2799 create_collection_request = models.CreateCollection(
#    2800     vectors=vectors_config,
#    2801     shard_number=shard_number,
#    (...)   2812     strict_mode_config=strict_mode_config,
#    2813 )
# -> 2815 result: Optional[bool] = self.http.collections_api.create_collection(
#    2816     collection_name=collection_name,
#    2817     create_collection=create_collection_request,
#    2818     timeout=timeout,
#    2819 ).result
#    2821 assert result is not None, "Create collection returned None"
#    2822 return result
#
# File c:\Users\Rizki Teguh\Desktop\tutorial-rag\.venv\Lib\site-packages\qdrant_client\http\api\collections_api.py:294, in SyncCollectionsApi.create_collection(self, collection_name, timeout, create_collection)
#     285 def create_collection(
#     286     self,
#     287     collection_name: str,
#     288     timeout: int = None,
#     289     create_collection: m.CreateCollection = None,
#     290 ) -> m.InlineResponse200:
#     291     """
#     292     Create new collection with given parameters
#     293     """
# --> 294     return self._build_for_create_collection(
#     295         collection_name=collection_name,
#     296         timeout=timeout,
#     297         create_collection=create_collection,
#     298     )
#
# File c:\Users\Rizki Teguh\Desktop\tutorial-rag\.venv\Lib\site-packages\qdrant_client\http\api\collections_api.py:96, in _CollectionsApi._build_for_create_collection(self, collection_name, timeout, create_collection)
#      94 if "Content-Type" not in headers:
#      95     headers["Content-Type"] = "application/json"
# ---> 96 return self.api_client.request(
#      97     type_=m.InlineResponse200,
#      98     method="PUT",
#      99     url="/collections/{collection_name}",
#     100     headers=headers if headers else None,
#     101     path_params=path_params,
#     102     params=query_params,
#     103     content=body,
#     104 )
#
# File c:\Users\Rizki Teguh\Desktop\tutorial-rag\.venv\Lib\site-packages\qdrant_client\http\api_client.py:95, in ApiClient.request(self, type_, method, url, path_params, **kwargs)
#      93     kwargs["timeout"] = int(kwargs["params"]["timeout"])
#      94 request = self._client.build_request(method, url, **kwargs)
# ---> 95 return self.send(request, type_)
#
# File c:\Users\Rizki Teguh\Desktop\tutorial-rag\.venv\Lib\site-packages\qdrant_client\http\api_client.py:130, in ApiClient.send(self, request, type_)
#     128     except ValidationError as e:
#     129         raise ResponseHandlingException(e)
# --> 130 raise UnexpectedResponse.for_response(response)
#
# UnexpectedResponse: Unexpected Response: 409 (Conflict)
# Raw response content:
# b'{"status":{"error":"Wrong input: Collection `my_collection` already exists!"},"time":0.000258305}'

# %%
client.collection_exists(collection_name="my_collection")
# Out:
# True

# %%
client.create_collection(collection_name="my_collection_1")
# Out:
# True

# %%
client.create_collection(collection_name="my_collection_2")
# Out:
# True

# %%
client.get_collections()
# Out:
# CollectionsResponse(collections=[CollectionDescription(name='my_collection_1'), CollectionDescription(name='my_collection'), CollectionDescription(name='my_collection_2')])

# %%
# menghapus collection

client.delete_collection(collection_name="my_collection_2")
# Out:
# True

# %%
client.get_collections()
# Out:
# CollectionsResponse(collections=[CollectionDescription(name='my_collection_1'), CollectionDescription(name='my_collection')])

# %% [markdown]
# ---

# %%
collection_name = "basic_collection"

# %%
client.create_collection(
    collection_name=collection_name,
    vectors_config=models.VectorParams(
        size=4,
        distance=models.Distance.COSINE
    )
)
# Out:
# True

# %%
# memasukkan vector atau embedding ke dalam collection

client.upsert(
    collection_name=collection_name,
    points=models.Batch(
        ids = [1,2,3,4,5],
        vectors = [
            [0.9, 0.1, 0.1, 0.1], # Vektor untuk ID 1
            [0.1, 0.9, 0.1, 0.1], # Vektor untuk ID 2
            [0.1, 0.1, 0.9, 0.1], # Vektor untuk ID 3
            [0.1, 0.1, 0.1, 0.9], # Vektor untuk ID 4
            [0.5, 0.5, 0.5, 0.5]  # Vektor untuk ID 5
        ],
        payloads =[
            {"color": "red", "size": 5},
            {"color": "green", "size": 5},
            {"color": "blue", "size": 8},
            {"color": "red", "size": 8},
            {"color": "green", "size": 2}
        ]
    ),
    wait=True
)
# Out:
# UpdateResult(operation_id=0, status=<UpdateStatus.COMPLETED: 'completed'>)

# %%
# retrieve sederhana

client.retrieve(
    collection_name=collection_name,
    ids=[1,4],
    with_payload=True,
    with_vectors=True
)
# Out:
# [Record(id=1, payload={'color': 'red', 'size': 5}, vector=[0.9819805, 0.10910895, 0.10910895, 0.10910895], shard_key=None, order_value=None),
#  Record(id=4, payload={'color': 'red', 'size': 8}, vector=[0.10910895, 0.10910895, 0.10910895, 0.9819805], shard_key=None, order_value=None)]

# %%
# scroll

points, next_offset = client.scroll(
    collection_name=collection_name,
    limit=3,
    with_payload=True,
    with_vectors=True
)

# %%
points
# Out:
# [Record(id=1, payload={'color': 'red', 'size': 5}, vector=[0.9819805, 0.10910895, 0.10910895, 0.10910895], shard_key=None, order_value=None),
#  Record(id=2, payload={'color': 'green', 'size': 5}, vector=[0.10910895, 0.9819805, 0.10910895, 0.10910895], shard_key=None, order_value=None),
#  Record(id=3, payload={'color': 'blue', 'size': 8}, vector=[0.10910895, 0.10910895, 0.9819805, 0.10910895], shard_key=None, order_value=None)]

# %%
next_offset
# Out:
# 4

# %%
# delete points

client.delete(
    collection_name=collection_name,
    points_selector=models.PointIdsList(points=[1,3])
)
# Out:
# UpdateResult(operation_id=1, status=<UpdateStatus.COMPLETED: 'completed'>)

# %%
client.scroll(
    collection_name=collection_name,
    with_payload=True,
    with_vectors=True
)
# Out:
# ([Record(id=2, payload={'color': 'green', 'size': 5}, vector=[0.10910895, 0.9819805, 0.10910895, 0.10910895], shard_key=None, order_value=None),
#   Record(id=4, payload={'color': 'red', 'size': 8}, vector=[0.10910895, 0.10910895, 0.10910895, 0.9819805], shard_key=None, order_value=None),
#   Record(id=5, payload={'color': 'green', 'size': 2}, vector=[0.5, 0.5, 0.5, 0.5], shard_key=None, order_value=None)],
#  None)

# %%
client.count(collection_name=collection_name, exact=True)
# Out:
# CountResult(count=3)

# %% [markdown]
# ---

# %%
from sentence_transformers import SentenceTransformer

# %%
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
collection_name = "docs_collection"

# %%
vector_size = embedding_model.get_sentence_embedding_dimension()

# %%
vector_size
# Out:
# 384

# %%
client.create_collection(
    collection_name=collection_name,
    vectors_config=models.VectorParams(
        size=vector_size,
        distance=models.Distance.COSINE
    )
)
# Out:
# True

# %%
# chunks

chunks = [
    {"doc_id": 1, "chunk_id": 1, "title": "Energi Terbarukan di Indonesia", "text": "Indonesia memiliki potensi besar dalam pengembangan energi terbarukan, seperti tenaga surya, air, dan angin."},
    {"doc_id": 1, "chunk_id": 2, "title": "Energi Terbarukan di Indonesia", "text": "Tenaga surya menjadi salah satu sumber energi yang paling menjanjikan karena wilayah Indonesia yang mendapat sinar matahari sepanjang tahun."},
    {"doc_id": 1, "chunk_id": 3, "title": "Energi Terbarukan di Indonesia", "text": "Namun, tantangan utama terletak pada biaya instalasi awal dan kurangnya infrastruktur penyimpanan energi yang efisien."},
    {"doc_id": 1, "chunk_id": 4, "title": "Energi Terbarukan di Indonesia", "text": "Pemerintah terus berupaya meningkatkan investasi dan memperluas program energi bersih untuk mencapai target emisi nol bersih pada 2060."},
    {"doc_id": 1, "chunk_id": 5, "title": "Energi Terbarukan di Indonesia", "text": "Selain itu, kolaborasi antara sektor publik dan swasta menjadi kunci dalam mempercepat transisi menuju sistem energi yang berkelanjutan."},
]

# %%
text_to_embed = [chunk['text'] for chunk in chunks]

# %%
text_to_embed
# Out:
# ['Indonesia memiliki potensi besar dalam pengembangan energi terbarukan, seperti tenaga surya, air, dan angin.',
#  'Tenaga surya menjadi salah satu sumber energi yang paling menjanjikan karena wilayah Indonesia yang mendapat sinar matahari sepanjang tahun.',
#  'Namun, tantangan utama terletak pada biaya instalasi awal dan kurangnya infrastruktur penyimpanan energi yang efisien.',
#  'Pemerintah terus berupaya meningkatkan investasi dan memperluas program energi bersih untuk mencapai target emisi nol bersih pada 2060.',
#  'Selain itu, kolaborasi antara sektor publik dan swasta menjadi kunci dalam mempercepat transisi menuju sistem energi yang berkelanjutan.']

# %%
embeddings = embedding_model.encode(text_to_embed, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%