# %%
from qdrant_client import QdrantClient
from sentence_transformers import SentenceTransformer

# %%
client = QdrantClient('localhost:6333')

model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
client.get_collections()
# Out:
# CollectionsResponse(collections=[CollectionDescription(name='docs_collection'), CollectionDescription(name='my_collection_1'), CollectionDescription(name='my_collection'), CollectionDescription(name='basic_collection')])

# %%
collection_name = 'docs_collection'

# %%
client.scroll(
    collection_name=collection_name,
    with_payload=True
)
# Out:
# ([Record(id=1, payload={'doc_id': 1, 'title': 'Energi Terbarukan di Indonesia', 'text': 'Indonesia memiliki potensi besar dalam pengembangan energi terbarukan, seperti tenaga surya, air, dan angin.'}, vector=None, shard_key=None, order_value=None),
#   Record(id=2, payload={'doc_id': 1, 'title': 'Energi Terbarukan di Indonesia', 'text': 'Tenaga surya menjadi salah satu sumber energi yang paling menjanjikan karena wilayah Indonesia yang mendapat sinar matahari sepanjang tahun.'}, vector=None, shard_key=None, order_value=None),
#   Record(id=3, payload={'doc_id': 1, 'title': 'Energi Terbarukan di Indonesia', 'text': 'Namun, tantangan utama terletak pada biaya instalasi awal dan kurangnya infrastruktur penyimpanan energi yang efisien.'}, vector=None, shard_key=None, order_value=None),
#   Record(id=4, payload={'doc_id': 1, 'title': 'Energi Terbarukan di Indonesia', 'text': 'Pemerintah terus berupaya meningkatkan investasi dan memperluas program energi bersih untuk mencapai target emisi nol bersih pada 2060.'}, vector=None, shard_key=None, order_value=None),
#   Record(id=5, payload={'doc_id': 1, 'title': 'Energi Terbarukan di Indonesia', 'text': 'Selain itu, kolaborasi antara sektor publik dan swasta menjadi kunci dalam mempercepat transisi menuju sistem energi yang berkelanjutan.'}, vector=None, shard_key=None, order_value=None)],
#  None)

# %%
query = "Apa saja tantangan yang dihadapi energi terbarukan?"

query_embedding = model.encode(query).tolist()

# %%
len(query_embedding)
# Out:
# 384

# %%
search_result = client.search(
    collection_name=collection_name,
    query_vector=query_embedding,
    limit=3
)
# Out:
# C:\Users\Rizki Teguh\AppData\Local\Temp\ipykernel_17116\3970002999.py:1: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   search_result = client.search(

# %%
search_result
# Out:
# [ScoredPoint(id=3, version=0, score=0.6624356, payload={'doc_id': 1, 'title': 'Energi Terbarukan di Indonesia', 'text': 'Namun, tantangan utama terletak pada biaya instalasi awal dan kurangnya infrastruktur penyimpanan energi yang efisien.'}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2, version=0, score=0.634974, payload={'doc_id': 1, 'title': 'Energi Terbarukan di Indonesia', 'text': 'Tenaga surya menjadi salah satu sumber energi yang paling menjanjikan karena wilayah Indonesia yang mendapat sinar matahari sepanjang tahun.'}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=1, version=0, score=0.58160067, payload={'doc_id': 1, 'title': 'Energi Terbarukan di Indonesia', 'text': 'Indonesia memiliki potensi besar dalam pengembangan energi terbarukan, seperti tenaga surya, air, dan angin.'}, vector=None, shard_key=None, order_value=None)]
